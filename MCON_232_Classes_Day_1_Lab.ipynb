# %% [markdown]
# <a href="https://colab.research.google.com/github/jspiegel3/MCON232_Classes/blob/main/MCON_232_Classes_Day_1_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MCON 232 Classes Day 1 Lab
# ### your name :
