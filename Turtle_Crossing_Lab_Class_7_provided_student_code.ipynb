# %% [markdown]
# <a href="https://colab.research.google.com/github/jspiegel3/MCON232_Classes/blob/main/Turtle_Crossing_Lab_Class_7_provided_student_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Note : We will develop this game in Pycharm, but here are the variables that will assist in building this game.  This game will NOT work in Colabs

# %%
import random
from turtle import Turtle, Screen

# --- HOT PINKS & FUSCHIAS (The "Power" Colors) ---
truck_palette = [ '#ff00ff', '#ff1aff', '#ff33ff', '#ff4dff', '#ff66ff', '#ff80ff', # High-energy Magentas
    '#ff00cc', '#ff0099', '#ff0066', '#ff1493', # Deep Pinks & DeepPink

    # --- COTTON CANDY & BUBBLEGUM PINKS ---
    '#ff66b2', '#ff80bf', '#ff99cc', '#ffb3d9', '#ffcce6', '#ffe6f2', # Soft & Sugary

    # --- PEACHY PINKS & CORALS ---
    '#ff4d4d', '#ff6666', '#ff8080', '#ff9999', # Warm "Strawberry" tones
    '#ff7f50', '#ff8c69', '#ffa07a', '#ffb3a1', # Coral & Salmon

    # --- BRIGHT PEACH & SUNSET ORANGE ---
    '#ffcc99', '#ffd9b3', '#ffe6cc', '#fff2e6', # Creamy Oranges

    # --- ELECTRIC & LEMON YELLOWS ---
    '#ffff00', '#ffff33', '#ffff66', '#ffff99', # Neon Yellows
    '#fffacd', '#fff5b3', '#fff099', '#ffeb80', # Lemon Chiffon tones

    # --- MINT & SOFT AQUAS ---
    '#e0ffff', '#b2ffff', '#80ffff', '#4dffff', # Icy Cyans
    '#98fb98', '#afffaf', '#c6ffc6', '#ddffdd', # Sweet Mints

    # --- PERIWINKLE & LAVENDER ---
    '#e6e6ff', '#ccccff', '#b2b2ff', '#9999ff', # Soft Purples
    '#d8b2ff', '#cc99ff', '#bf80ff', '#b266ff', # Sugary Lilac

    # --- VIVID VIOLETS & ORCHIDS ---
    '#a64dff', '#9933ff', '#8c1aff', '#8000ff', # Intense Purple pop
    '#da70d6', '#ee82ee', '#ff82ff', '#ffb3ff'  # Orchids & Bright Violet
]

# %%
screen = Screen()
screen.setup(width=700, height=600)
screen.bgcolor("white")
screen.title("Turtle Crossing")
screen.tracer(0)

# %% [markdown]
# Lane Lines and Truck lanes :

# %%
# suggested to start off : (I will show you where these go)
lane_lines = [-150, -50, 50, 150]
truck_lanes = [-200, -100, 0, 100, 200]

# later - to add more lanes and more trucks :
lane_lines = [-175, -125, -75, -25, 25, 75, 125, 175]
truck_lanes = [-200, -150, -100, -50, 0, 50, 100, 150, 200]

# %% [markdown]
# Speed

# %%
speed=random.uniform(.1, .3) # of trucks
# faster :
speed = random.uniform(0.3, 0.7)

# %% [markdown]
# Colors

# %%
# these are my color choices, feel free to look at coolors.co to find your own (under pallets)

# --- HOT PINKS & FUSCHIAS (The "Power" Colors) ---
truck_palette = [ '#ff00ff', '#ff1aff', '#ff33ff', '#ff4dff', '#ff66ff', '#ff80ff', # High-energy Magentas
    '#ff00cc', '#ff0099', '#ff0066', '#ff1493', # Deep Pinks & DeepPink

    # --- COTTON CANDY & BUBBLEGUM PINKS ---
    '#ff66b2', '#ff80bf', '#ff99cc', '#ffb3d9', '#ffcce6', '#ffe6f2', # Soft & Sugary

    # --- PEACHY PINKS & CORALS ---
    '#ff4d4d', '#ff6666', '#ff8080', '#ff9999', # Warm "Strawberry" tones
    '#ff7f50', '#ff8c69', '#ffa07a', '#ffb3a1', # Coral & Salmon

    # --- BRIGHT PEACH & SUNSET ORANGE ---
    '#ffcc99', '#ffd9b3', '#ffe6cc', '#fff2e6', # Creamy Oranges

    # --- ELECTRIC & LEMON YELLOWS ---
    '#ffff00', '#ffff33', '#ffff66', '#ffff99', # Neon Yellows
    '#fffacd', '#fff5b3', '#fff099', '#ffeb80', # Lemon Chiffon tones

    # --- MINT & SOFT AQUAS ---
    '#e0ffff', '#b2ffff', '#80ffff', '#4dffff', # Icy Cyans
    '#98fb98', '#afffaf', '#c6ffc6', '#ddffdd', # Sweet Mints

    # --- PERIWINKLE & LAVENDER ---
    '#e6e6ff', '#ccccff', '#b2b2ff', '#9999ff', # Soft Purples
    '#d8b2ff', '#cc99ff', '#bf80ff', '#b266ff', # Sugary Lilac

    # --- VIVID VIOLETS & ORCHIDS ---
    '#a64dff', '#9933ff', '#8c1aff', '#8000ff', # Intense Purple pop
    '#da70d6', '#ee82ee', '#ff82ff', '#ffb3ff'  # Orchids & Bright Violet
]

# highway color
self.color("#3d348b")
# or
self.color("#CB94F7")

# turtle
self.color("#86e7b8")

# %% [markdown]
# # Answer to Turtle Traffic
# ## in case you are stuck
# ### note : some colors may be different from the version we are building

# %%
import random
from turtle import Turtle, Screen

# --- HOT PINKS & FUSCHIAS (The "Power" Colors) ---
truck_palette = [ '#ff00ff', '#ff1aff', '#ff33ff', '#ff4dff', '#ff66ff', '#ff80ff', # High-energy Magentas
    '#ff00cc', '#ff0099', '#ff0066', '#ff1493', # Deep Pinks & DeepPink

    # --- COTTON CANDY & BUBBLEGUM PINKS ---
    '#ff66b2', '#ff80bf', '#ff99cc', '#ffb3d9', '#ffcce6', '#ffe6f2', # Soft & Sugary

    # --- PEACHY PINKS & CORALS ---
    '#ff4d4d', '#ff6666', '#ff8080', '#ff9999', # Warm "Strawberry" tones
    '#ff7f50', '#ff8c69', '#ffa07a', '#ffb3a1', # Coral & Salmon

    # --- BRIGHT PEACH & SUNSET ORANGE ---
    '#ffcc99', '#ffd9b3', '#ffe6cc', '#fff2e6', # Creamy Oranges

    # --- ELECTRIC & LEMON YELLOWS ---
    '#ffff00', '#ffff33', '#ffff66', '#ffff99', # Neon Yellows
    '#fffacd', '#fff5b3', '#fff099', '#ffeb80', # Lemon Chiffon tones

    # --- MINT & SOFT AQUAS ---
    '#e0ffff', '#b2ffff', '#80ffff', '#4dffff', # Icy Cyans
    '#98fb98', '#afffaf', '#c6ffc6', '#ddffdd', # Sweet Mints

    # --- PERIWINKLE & LAVENDER ---
    '#e6e6ff', '#ccccff', '#b2b2ff', '#9999ff', # Soft Purples
    '#d8b2ff', '#cc99ff', '#bf80ff', '#b266ff', # Sugary Lilac

    # --- VIVID VIOLETS & ORCHIDS ---
    '#a64dff', '#9933ff', '#8c1aff', '#8000ff', # Intense Purple pop
    '#da70d6', '#ee82ee', '#ff82ff', '#ffb3ff'  # Orchids & Bright Violet
]

class Player(Turtle):
    def __init__(self):
        super().__init__()
        self.shape("turtle")
        self.color("green")
        self.penup()
        self.goto(0, -260)
        self.setheading(90)

    def move_up(self):
        self.goto(self.xcor(), self.ycor() + 20)

    def move_down(self):
        self.goto(self.xcor(), self.ycor() - 20)

    def move_left(self):
        self.goto(self.xcor() - 20, self.ycor())

    def move_right(self):
        self.goto(self.xcor() + 20, self.ycor())

    def reset_position(self):
        self.goto(0, -260)


class Truck(Turtle):
    def __init__(self, x, y, speed, color):
        super().__init__()
        self.shape("square")
        self.shapesize(stretch_wid=1, stretch_len=3)
        self.color(color)
        self.penup()
        self.goto(x, y)
        self.speed_value = speed

    def move(self):
      self.goto(self.xcor() - self.speed_value, self.ycor())

      if self.xcor() < -340:
          self.goto(random.randint(320, 500), self.ycor())
          self.color(random.choice(truck_palette))
          self.speed_value = random.uniform(0.3, 0.7)  #<== SPEED .1 to .3 moderate


class Scoreboard(Turtle):
    def __init__(self):
        super().__init__()
        self.penup()
        self.hideturtle()
        self.color("black")
        self.truck_score = 0
        self.player_score = 0
        self.goto(0, 260)
        self.update_score()

    def update_score(self):
        self.clear()
        self.write(
            f"Player: {self.player_score}    Trucks: {self.truck_score}",
            align="center",
            font=("Arial", 16, "bold")
        )

    def player_point(self):
        self.player_score += 1
        self.update_score()

    def truck_point(self):
        self.truck_score += 1
        self.update_score()


class HighwayDrawer(Turtle):
    def __init__(self):
        super().__init__()
        self.hideturtle()
        self.penup()
        self.speed(0)

    def draw_highway(self):
        self.goto(-350, -250)
        self.color("#3d348b")
        self.begin_fill()

        self.pendown()
        for _ in range(2):
            self.forward(700)
            self.left(90)
            self.forward(500)
            self.left(90)
        self.end_fill()
        self.penup()

        self.color("white")
        self.pensize(5)
        # BETTER LANE LINES : lane_lines = [-175, -125, -75, -25, 25, 75, 125, 175]
        lane_lines = [-150, -50, 50, 150]

        for y in lane_lines:
            self.goto(-330, y)
            for _ in range(20):
                self.pendown()
                self.forward(15)
                self.penup()
                self.forward(20)


screen = Screen()
screen.setup(width=700, height=600)
screen.bgcolor("white")
screen.title("Turtle Crossing")
screen.tracer(0)

highway = HighwayDrawer()
highway.draw_highway()

player = Player()
scoreboard = Scoreboard()

truck_lanes = [-200, -100, 0, 100, 200]
# better truck lanes : truck_lanes = [-200, -150, -100, -50, 0, 50, 100, 150, 200]
trucks = []

for lane in truck_lanes:
    truck = Truck(
        x=random.randint(-300, 300),
        y=lane,
        speed=random.uniform(.1, .3),
        color=random.choice(truck_palette)
    )
    trucks.append(truck)

screen.listen()
screen.onkey(player.move_up, "Up")
screen.onkey(player.move_down, "Down")
screen.onkey(player.move_left, "Left")
screen.onkey(player.move_right, "Right")

game_is_on = True
while game_is_on:
    screen.update()

    for truck in trucks:
        truck.move()

        if player.distance(truck) < 30:
            scoreboard.truck_point()
            player.reset_position()

    if player.ycor() > 260:
        scoreboard.player_point()
        player.reset_position()

screen.exitonclick()  # waiting for closing of the window
